# %% [markdown]
# # Table of Contents

# %%
from PIL import Image
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
# csv_file_path = '../dataset/driver_imgs_list.csv'
# train_data_path = '../dataset/train/'
# test_data_path = '../dataset/test/'

train_data_path = '../dataset/samples/c'

drivers_csv = pd.read_csv(csv_path)
classes = (np.unique(np.asarray(drivers_csv)[:,1]))
NUM_CLASSES = len(classes)
print(NUM_CLASSES)

# for k in NUM_CLASSES:
#     curr_dir_path = train_data_path + str(k) + '/'
    

# get_training_data(train_data_path, NUM_CLASSES)
I = Image.open(sample_path).convert('1')
plt.imshow(I)
I = np.asarray(I)
print(I.shape)
# Out:
# 10
# (480, 640)

# %%
# Storing an image into an array
# path = "./resources/images/c0_example.jpg"
# I = np.asarray(Image.open(path)) # 3d: height, width, rbg
# print(type(I))
# print((I).shape)

# %%
# From array to a picture
# img = Image.fromarray(arr)
# img.save("output.png")
